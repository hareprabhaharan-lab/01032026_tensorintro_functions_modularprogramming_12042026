# %%
student_data = {
    "student_id": list(range(1, 21)),
    "name": [
        "Arjun", "Meera", "Ravi", "Sneha", "Karan", "Priya", "Anita", "Vikram", "Nisha", "Aditya",
        "Rekha", "Sohail", "Tanvi", "Harish", "Deepa", "Manoj", "Shreya", "Kabir", "Isha", "Rohan"
    ],
    "department": [
        "AI", "Data", "AI", "Cloud", "Data", "AI", "Cloud", "AI", "Data", "Cloud",
        "AI", "Data", "Cloud", "AI", "Data", "Cloud", "AI", "Data", "Cloud", "AI"
    ],
    "marks": [85, 78, 92, 74, 88, 95, 67, 80, 72, 91, 84, 79, 86, 90, 75, 82, 89, 77, 93, 88],
    "attendance_percentage": [90, 85, 88, 70, 92, 96, 65, 87, 73, 95, 89, 82, 91, 94, 78, 84, 93, 80, 97, 86],
    "city": [
        "Chennai", "Mumbai", "Delhi", "Chennai", "Bangalore", "Delhi", "Mumbai", "Chennai", "Bangalore", "Delhi",
        "Chennai", "Mumbai", "Bangalore", "Delhi", "Chennai", "Mumbai", "Bangalore", "Delhi", "Chennai", "Mumbai"
    ]
}

# %% [markdown]
# # A – DataFrame Creation & Exploration
#
# 1.	Convert the dictionary into a Pandas DataFrame.
#
# 3.	Display:
#     o	First 5 rows
#     o	Last 5 rows
#     o	Summary statistics using describe()
# 4.	Display column names and data types.
# 5.	Set student_id as the index.
#
# # B – Filtering & Selection
#
# 5.	List all students in the AI department.
# 6.	List students with marks > 85 and attendance > 90.
# 7.	Count number of students in each department.
# 8.	List students from Delhi who have marks above 80.
#
# # C – Sorting & New Columns
#
# 9.	Sort students by marks descending.
# 10.	Add a column passed:
#     •	Marks >= 75 → "Yes"
#     •	Marks < 75 → "No"
# 11.	Find top 3 students based on marks.
#
# # D – Aggregation & Grouping
#
# 12.	Calculate average marks per department.
# 13.	Calculate average attendance per city.
# 14.	Count number of students passed/failed per department.
#
# # E – Advanced Analysis
#
# 15.	Identify students who are above department average marks.
# 16.	Identify the city with highest average marks.
# 17.	Plot a bar chart of average marks by department (use matplotlib or pandas.plot).
# 18.	Plot a scatter plot of marks vs attendance.

# %% [markdown]
# # This is how you import a txt into pandas

# %%
#Sometimes, your document may be just commaseperated

import pandas as pd

# Reading a comma-separated text file
df = pd.read_csv("Commaseperated.txt")

# Display first 5 rows
print(df.head())
# Out:
#    student_id   name department  marks  attendance_percentage       city
# 0           1  Arjun         AI     85                     90    Chennai
# 1           2  Meera       Data     78                     85     Mumbai
# 2           3   Ravi         AI     92                     88      Delhi
# 3           4  Sneha      Cloud     74                     70    Chennai
# 4           5  Karan       Data     88                     92  Bangalore

# %%
#Sometimes, your document may be just tabseperated
df = pd.read_csv("Tabseperated.txt", sep="\t")
print(df.head())
# Out:
#    student_id   name department  marks  attendance_percentage     city
# 0           1  Arjun         AI     85                     90  Chennai
# 1           2  Meera       Data     78                     85   Mumbai
# 2           3   Ravi         AI     92                     88    Delhi

# %%
# Sometimes columns are aligned but no delimiter.

df = pd.read_fwf("nodelimiter.txt")
print(df.head())
# Out:
#    1  Arjun    AI  85  90 Chennai
# 0  2  Meera  Data  78  85  Mumbai
# 1  3   Ravi    AI  92  88   Delhi
